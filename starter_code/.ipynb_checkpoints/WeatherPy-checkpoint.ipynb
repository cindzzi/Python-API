# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="  
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=134666dd0e2cc872e1f9ae630e853b34&units=Imperial&q='

# %%
# Add columns for lat, cloudiness, country, temp, date, humidity, lng, max temp, wind speed
cities_data=pd.DataFrame(cities)
cities_data['Cloudiness']=""
cities_data['Country']=""
cities_data['Lat']=""
cities_data['Lng']=" "
cities_data['Date']=""
cities_data['Humidity']=""
cities_data['Max temp']=""
cities_data['Wind speed']=""

cities_data = cities_df.rename(columns={0: "City name"})

# %%
print("Beginning Data Complete")
print("-------------------------")

# use iterrows to iterate through pandas dataframe
for index, row in cities_df.iterrows():
    city = row['City name']
    
    response = requests.get(query_url + city).json()
    
    try:
        
        print(f"Processing Record {index} Of Set {index}| {city}.")
        
        cities_df.loc[index,'City name'] = response ['name']
        cities_df.loc[index,'Cloudiness'] = response ['clouds']['all']
        cities_df.loc[index,'Country'] = response ['sys']['country']
        cities_df.loc[index,'Lat'] = response ['coord']['lat']
        cities_df.loc[index,'Lng'] = response ['coord']['lon']
        cities_df.loc[index,'Date'] = response ['dt']
        cities_df.loc[index,'Humidity'] = response ['main']['humidity']
        cities_df.loc[index,'Max temp'] = response ['main']['temp_max']
        cities_df.loc[index,'Wind speed'] = response ['wind']['speed']
        

    except (KeyError, IndexError):
        print("City Not Found. Skipping.")
        
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Complete
# -------------------------
# Processing Record 0 Of Set 0| Barreirinhas.
# Processing Record 1 Of Set 1| Alyangula.
# Processing Record 2 Of Set 2| Bredasdorp.
# Processing Record 3 Of Set 3| Rikitea.
# Processing Record 4 Of Set 4| Saldanha.
# Processing Record 5 Of Set 5| barentsburg.
# City Not Found. Skipping.
# Processing Record 6 Of Set 6| Bluff.
# Processing Record 7 Of Set 7| Busselton.
# Processing Record 8 Of Set 8| Vangaindrano.
# Processing Record 9 Of Set 9| Ribeira Grande.
# Processing Record 10 Of Set 10| Alofi.
# Processing Record 11 Of Set 11| Qaanaaq.
# Processing Record 12 Of Set 12| Lusambo.
# Processing Record 13 Of Set 13| Kavaratti.
# Processing Record 14 Of Set 14| Gamboma.
# Processing Record 15 Of Set 15| Saint Anthony.
# Processing Record 16 Of Set 16| Avera.
# Processing Record 17 Of Set 17| Hambantota.
# Processing Record 18 Of Set 18| Upernavik.
# Processing Record 19 Of Set 19| bargal.
# City Not Found. Skipping.
# Processing Record 20 Of Set 20| grand river south east.
# City Not Found. Skipping.
# Processing Record 21 Of Set 21| Tuktoyaktuk.
# Processing Record 22 Of Set 22| Oxapampa.
# Processing Record 23 Of Set 23| Ushtobe.
# Processing Record 24 Of Set 24| Nemuro.
# Processing Record 25 Of Set 25| Acajutla.
# Processing Record 26 Of Set 26| Churapcha.
# Processing Record 27 Of Set 27| Ushuaia.
# Processing Record 28 Of Set 28| Port Alfred.
# Processing Record 29 Of Set 29| Kodiak.
# Processing Record 30 Of Set 30| Manta.
# Processing Record 31 Of Set 31| Mataura.
# Processing Record 32 Of Set 32| Castro.
# Processing Record 33 Of Set 33| Saint George.
# Processing Record 34 Of Set 34| Hermanus.
# Processing Record 35 Of Set 35| Kapaa.
# Processing Record 36 Of Set 36| Staryy Nadym.
# Processing Record 37 Of Set 37| tsihombe.
# City Not Found. Skipping.
# Processing Record 38 Of Set 38| Katra.
# Processing Record 39 Of Set 39| Hasaki.
# Processing Record 40 Of Set 40| Imeni Poliny Osipenko.
# Processing Record 41 Of Set 41| Ponta do Sol.
# Processing Record 42 Of Set 42| Dikson.
# Processing Record 43 Of Set 43| Clarence Town.
# Processing Record 44 Of Set 44| bolungarvik.
# City Not Found. Skipping.
# Processing Record 45 Of Set 45| Punta Arenas.
# Processing Record 46 Of Set 46| Parakou.
# Processing Record 47 Of Set 47| Nome.
# Processing Record 48 Of Set 48| Oum Hadjer.
# Processing Record 49 Of Set 49| Port Elizabeth.
# Processing Record 50 Of Set 50| taolanaro.
# City Not Found. Skipping.
# Processing Record 51 Of Set 51| Seoul.
# Processing Record 52 Of Set 52| Manuk Mangkaw.
# Processing Record 53 Of Set 53| Chuy.
# Processing Record 54 Of Set 54| Khatanga.
# Processing Record 55 Of Set 55| Narsaq.
# Processing Record 56 Of Set 56| palasa.
# City Not Found. Skipping.
# Processing Record 57 Of Set 57| Akdepe.
# Processing Record 58 Of Set 58| Tual.
# Processing Record 59 Of Set 59| Santa Maria.
# Processing Record 60 Of Set 60| Avarua.
# Processing Record 61 Of Set 61| acarau.
# City Not Found. Skipping.
# Processing Record 62 Of Set 62| Arraial do Cabo.
# Processing Record 63 Of Set 63| Krasnomayskiy.
# Processing Record 64 Of Set 64| Hilo.
# Processing Record 65 Of Set 65| bengkulu.
# City Not Found. Skipping.
# Processing Record 66 Of Set 66| Pinyug.
# Processing Record 67 Of Set 67| Inhambane.
# Processing Record 68 Of Set 68| Jamestown.
# Processing Record 69 Of Set 69| Chokurdakh.
# Processing Record 70 Of Set 70| Beringovskiy.
# Processing Record 71 Of Set 71| Hobart.
# Processing Record 72 Of Set 72| Brae.
# Processing Record 73 Of Set 73| Atuona.
# Processing Record 74 Of Set 74| Arlit.
# Processing Record 75 Of Set 75| Ternate.
# Processing Record 76 Of Set 76| Aklavik.
# Processing Record 77 Of Set 77| Carbonia.
# Processing Record 78 Of Set 78| Guerrero Negro.
# Processing Record 79 Of Set 79| Sitka.
# Processing Record 80 Of Set 80| Port Blair.
# Processing Record 81 Of Set 81| Texarkana.
# Processing Record 82 Of Set 82| Lorengau.
# Processing Record 83 Of Set 83| Turayf.
# Processing Record 84 Of Set 84| Vaini.
# Processing Record 85 Of Set 85| Cherskiy.
# Processing Record 86 Of Set 86| Bud.
# Processing Record 87 Of Set 87| Serenje.
# Processing Record 88 Of Set 88| Porto Novo.
# Processing Record 89 Of Set 89| Bandar.
# Processing Record 90 Of Set 90| nizhneyansk.
# City Not Found. Skipping.
# Processing Record 91 Of Set 91| Sandwick.
# Processing Record 92 Of Set 92| Barrow.
# Processing Record 93 Of Set 93| Puerto Ayora.
# Processing Record 94 Of Set 94| Comodoro Rivadavia.
# Processing Record 95 Of Set 95| Dingle.
# Processing Record 96 Of Set 96| Cape Town.
# Processing Record 97 Of Set 97| Kautokeino.
# Processing Record 98 Of Set 98| Faanui.
# Processing Record 99 Of Set 99| Rome.
# Processing Record 100 Of Set 100| New Norfolk.
# Processing Record 101 Of Set 101| La Ronge.
# Processing Record 102 Of Set 102| Srednekolymsk.
# Processing Record 103 Of Set 103| Fortuna.
# Processing Record 104 Of Set 104| Vanavara.
# Processing Record 105 Of Set 105| Yumen.
# Processing Record 106 Of Set 106| Airai.
# Processing Record 107 Of Set 107| Liloy.
# Processing Record 108 Of Set 108| Cabo San Lucas.
# Processing Record 109 Of Set 109| Bambous Virieux.
# Processing Record 110 Of Set 110| saleaula.
# City Not Found. Skipping.
# Processing Record 111 Of Set 111| Sudak.
# Processing Record 112 Of Set 112| Hovd.
# Processing Record 113 Of Set 113| asau.
# City Not Found. Skipping.
# Processing Record 114 Of Set 114| Geraldton.
# Processing Record 115 Of Set 115| Fontem.
# Processing Record 116 Of Set 116| Saskylakh.
# Processing Record 117 Of Set 117| Tasiilaq.
# Processing Record 118 Of Set 118| Lebu.
# Processing Record 119 Of Set 119| Luderitz.
# Processing Record 120 Of Set 120| marcona.
# City Not Found. Skipping.
# Processing Record 121 Of Set 121| bac lieu.
# City Not Found. Skipping.
# Processing Record 122 Of Set 122| Ajaccio.
# Processing Record 123 Of Set 123| illoqqortoormiut.
# City Not Found. Skipping.
# Processing Record 124 Of Set 124| Seini.
# Processing Record 125 Of Set 125| mocambique.
# City Not Found. Skipping.
# Processing Record 126 Of Set 126| Vila Franca do Campo.
# Processing Record 127 Of Set 127| Bilma.
# Processing Record 128 Of Set 128| Tiksi.
# Processing Record 129 Of Set 129| Saint-Philippe.
# Processing Record 130 Of Set 130| Podosinovets.
# Processing Record 131 Of Set 131| tamazulapam.
# City Not Found. Skipping.
# Processing Record 132 Of Set 132| Mount Gambier.
# Processing Record 133 Of Set 133| Isangel.
# Processing Record 134 Of Set 134| Bandarbeyla.
# Processing Record 135 Of Set 135| Khambhat.
# Processing Record 136 Of Set 136| Mae Ramat.
# Processing Record 137 Of Set 137| Piedras Negras.
# Processing Record 138 Of Set 138| Yamada.
# Processing Record 139 Of Set 139| Yellowknife.
# Processing Record 140 Of Set 140| Albany.
# Processing Record 141 Of Set 141| San Patricio.
# Processing Record 142 Of Set 142| Chone.
# Processing Record 143 Of Set 143| Port Hardy.
# Processing Record 144 Of Set 144| Bethel.
# Processing Record 145 Of Set 145| Axim.
# Processing Record 146 Of Set 146| Kraslava.
# Processing Record 147 Of Set 147| stornoway.
# City Not Found. Skipping.
# Processing Record 148 Of Set 148| Liman.
# Processing Record 149 Of Set 149| Novovasylivka.
# Processing Record 150 Of Set 150| Provideniya.
# Processing Record 151 Of Set 151| Port Hedland.
# Processing Record 152 Of Set 152| Presidencia Roque Saenz Pena.
# Processing Record 153 Of Set 153| Longyearbyen.
# Processing Record 154 Of Set 154| Nikolskoye.
# Processing Record 155 Of Set 155| Miajadas.
# Processing Record 156 Of Set 156| Gramsh.
# Processing Record 157 Of Set 157| Georgetown.
# Processing Record 158 Of Set 158| Grindavik.
# Processing Record 159 Of Set 159| Simao.
# Processing Record 160 Of Set 160| disna.
# City Not Found. Skipping.
# Processing Record 161 Of Set 161| Anqing.
# Processing Record 162 Of Set 162| Mildura.
# Processing Record 163 Of Set 163| Mareeba.
# Processing Record 164 Of Set 164| Altay.
# Processing Record 165 Of Set 165| Kalino.
# Processing Record 166 Of Set 166| Huarmey.
# Processing Record 167 Of Set 167| Atherton.
# Processing Record 168 Of Set 168| Dwarka.
# Processing Record 169 Of Set 169| Tanout.
# Processing Record 170 Of Set 170| Waingapu.
# Processing Record 171 Of Set 171| Taoudenni.
# Processing Record 172 Of Set 172| Kavieng.
# Processing Record 173 Of Set 173| San Cristobal.
# Processing Record 174 Of Set 174| Puerto Escondido.
# Processing Record 175 Of Set 175| Solnechnyy.
# Processing Record 176 Of Set 176| Shingu.
# Processing Record 177 Of Set 177| Pokhara.
# Processing Record 178 Of Set 178| safwah.
# City Not Found. Skipping.
# Processing Record 179 Of Set 179| Pevek.
# Processing Record 180 Of Set 180| Ahipara.
# Processing Record 181 Of Set 181| Yar-Sale.
# Processing Record 182 Of Set 182| Coihaique.
# Processing Record 183 Of Set 183| Namibe.
# Processing Record 184 Of Set 184| haibowan.
# City Not Found. Skipping.
# Processing Record 185 Of Set 185| Kaitangata.
# Processing Record 186 Of Set 186| Shimoda.
# Processing Record 187 Of Set 187| Clyde River.
# Processing Record 188 Of Set 188| Haines Junction.
# Processing Record 189 Of Set 189| Makakilo City.
# Processing Record 190 Of Set 190| Calbuco.
# Processing Record 191 Of Set 191| Ostrovnoy.
# Processing Record 192 Of Set 192| Santa Ana.
# Processing Record 193 Of Set 193| Thompson.
# Processing Record 194 Of Set 194| Vila Velha.
# Processing Record 195 Of Set 195| mys shmidta.
# City Not Found. Skipping.
# Processing Record 196 Of Set 196| umzimvubu.
# City Not Found. Skipping.
# Processing Record 197 Of Set 197| Sao Filipe.
# Processing Record 198 Of Set 198| Randazzo.
# Processing Record 199 Of Set 199| Iqaluit.
# Processing Record 200 Of Set 200| Opuwo.
# Processing Record 201 Of Set 201| Deputatskiy.
# Processing Record 202 Of Set 202| Torbay.
# Processing Record 203 Of Set 203| Awjilah.
# Processing Record 204 Of Set 204| Trincomalee.
# Processing Record 205 Of Set 205| Bowen.
# Processing Record 206 Of Set 206| Faya.
# Processing Record 207 Of Set 207| amderma.
# City Not Found. Skipping.
# Processing Record 208 Of Set 208| East London.
# Processing Record 209 Of Set 209| Puerto Suarez.
# Processing Record 210 Of Set 210| kamenskoye.
# City Not Found. Skipping.
# Processing Record 211 Of Set 211| Saint Andrews.
# Processing Record 212 Of Set 212| San Policarpo.
# Processing Record 213 Of Set 213| Caravelas.
# Processing Record 214 Of Set 214| Mount Isa.
# Processing Record 215 Of Set 215| Necocli.
# Processing Record 216 Of Set 216| Ketchikan.
# Processing Record 217 Of Set 217| San Jeronimo.
# Processing Record 218 Of Set 218| tarudant.
# City Not Found. Skipping.
# Processing Record 219 Of Set 219| stoyba.
# City Not Found. Skipping.
# Processing Record 220 Of Set 220| Samarai.
# Processing Record 221 Of Set 221| Cooma.
# Processing Record 222 Of Set 222| Presidente Franco.
# Processing Record 223 Of Set 223| Makasar.
# Processing Record 224 Of Set 224| San Blas.
# Processing Record 225 Of Set 225| Benghazi.
# Processing Record 226 Of Set 226| Ogdensburg.
# Processing Record 227 Of Set 227| Djibo.
# Processing Record 228 Of Set 228| samusu.
# City Not Found. Skipping.
# Processing Record 229 Of Set 229| Boddam.
# Processing Record 230 Of Set 230| Zeya.
# Processing Record 231 Of Set 231| Sao Joao da Barra.
# Processing Record 232 Of Set 232| Kondinskoye.
# Processing Record 233 Of Set 233| Namatanai.
# Processing Record 234 Of Set 234| Mahebourg.
# Processing Record 235 Of Set 235| Lompoc.
# Processing Record 236 Of Set 236| Koslan.
# Processing Record 237 Of Set 237| Xichang.
# Processing Record 238 Of Set 238| balimo.
# City Not Found. Skipping.
# Processing Record 239 Of Set 239| cagayan de tawi-tawi.
# City Not Found. Skipping.
# Processing Record 240 Of Set 240| Portland.
# Processing Record 241 Of Set 241| Lexington Park.
# Processing Record 242 Of Set 242| Novikovo.
# Processing Record 243 Of Set 243| belushya guba.
# City Not Found. Skipping.
# Processing Record 244 Of Set 244| Mendi.
# Processing Record 245 Of Set 245| Itabira.
# Processing Record 246 Of Set 246| Lahat.
# Processing Record 247 Of Set 247| manzil tamim.
# City Not Found. Skipping.
# Processing Record 248 Of Set 248| Fairbanks.
# Processing Record 249 Of Set 249| Buala.
# Processing Record 250 Of Set 250| Denpasar.
# Processing Record 251 Of Set 251| meyungs.
# City Not Found. Skipping.
# Processing Record 252 Of Set 252| Chenzhou.
# Processing Record 253 Of Set 253| Moranbah.
# Processing Record 254 Of Set 254| Puerto Colombia.
# Processing Record 255 Of Set 255| Maniitsoq.
# Processing Record 256 Of Set 256| Ilulissat.
# Processing Record 257 Of Set 257| Biryusinsk.
# Processing Record 258 Of Set 258| Tlacotepec.
# Processing Record 259 Of Set 259| Zhanakorgan.
# Processing Record 260 Of Set 260| Novyy Urengoy.
# Processing Record 261 Of Set 261| Azle.
# Processing Record 262 Of Set 262| Vardo.
# Processing Record 263 Of Set 263| Marzuq.
# Processing Record 264 Of Set 264| Eston.
# Processing Record 265 Of Set 265| Naze.
# Processing Record 266 Of Set 266| Vestmanna.
# Processing Record 267 Of Set 267| Cidreira.
# Processing Record 268 Of Set 268| Krasnoslobodsk.
# Processing Record 269 Of Set 269| Kano.
# Processing Record 270 Of Set 270| Colares.
# Processing Record 271 Of Set 271| Nanortalik.
# Processing Record 272 Of Set 272| Klaksvik.
# Processing Record 273 Of Set 273| Farafangana.
# Processing Record 274 Of Set 274| Corinto.
# Processing Record 275 Of Set 275| Chitral.
# Processing Record 276 Of Set 276| Jardim.
# Processing Record 277 Of Set 277| Husavik.
# Processing Record 278 Of Set 278| Tungor.
# Processing Record 279 Of Set 279| Grootfontein.
# Processing Record 280 Of Set 280| attawapiskat.
# City Not Found. Skipping.
# Processing Record 281 Of Set 281| Martapura.
# Processing Record 282 Of Set 282| Butaritari.
# Processing Record 283 Of Set 283| Acapulco.
# Processing Record 284 Of Set 284| Adrar.
# Processing Record 285 Of Set 285| Kudahuvadhoo.
# Processing Record 286 Of Set 286| Pavlovsk.
# Processing Record 287 Of Set 287| Egvekinot.
# Processing Record 288 Of Set 288| Aykhal.
# Processing Record 289 Of Set 289| Pacific Grove.
# Processing Record 290 Of Set 290| Codrington.
# Processing Record 291 Of Set 291| sumbawa.
# City Not Found. Skipping.
# Processing Record 292 Of Set 292| Birjand.
# Processing Record 293 Of Set 293| Caibarien.
# Processing Record 294 Of Set 294| Coruripe.
# Processing Record 295 Of Set 295| kousseri.
# City Not Found. Skipping.
# Processing Record 296 Of Set 296| Tank.
# Processing Record 297 Of Set 297| Kloulklubed.
# Processing Record 298 Of Set 298| Kamina.
# Processing Record 299 Of Set 299| Bedele.
# Processing Record 300 Of Set 300| Camabatela.
# Processing Record 301 Of Set 301| Tura.
# Processing Record 302 Of Set 302| Yerofey Pavlovich.
# Processing Record 303 Of Set 303| Cockburn Town.
# Processing Record 304 Of Set 304| West Wendover.
# Processing Record 305 Of Set 305| Nizhnyaya Tavda.
# Processing Record 306 Of Set 306| Kiama.
# Processing Record 307 Of Set 307| Kant.
# Processing Record 308 Of Set 308| Pochutla.
# Processing Record 309 Of Set 309| Gorontalo.
# Processing Record 310 Of Set 310| cheuskiny.
# City Not Found. Skipping.
# Processing Record 311 Of Set 311| Dongsheng.
# Processing Record 312 Of Set 312| Sibolga.
# Processing Record 313 Of Set 313| Bontang.
# Processing Record 314 Of Set 314| Thinadhoo.
# Processing Record 315 Of Set 315| rungata.
# City Not Found. Skipping.
# Processing Record 316 Of Set 316| Gillette.
# Processing Record 317 Of Set 317| Kattivakkam.
# Processing Record 318 Of Set 318| Dunedin.
# Processing Record 319 Of Set 319| Broome.
# Processing Record 320 Of Set 320| Carnarvon.
# Processing Record 321 Of Set 321| toliary.
# City Not Found. Skipping.
# Processing Record 322 Of Set 322| Gurupi.
# Processing Record 323 Of Set 323| Aquiraz.
# Processing Record 324 Of Set 324| Mar del Plata.
# Processing Record 325 Of Set 325| Tiznit.
# Processing Record 326 Of Set 326| Nieuw Amsterdam.
# Processing Record 327 Of Set 327| La Cruz.
# Processing Record 328 Of Set 328| Jining.
# Processing Record 329 Of Set 329| Inirida.
# Processing Record 330 Of Set 330| Necochea.
# Processing Record 331 Of Set 331| talawdi.
# City Not Found. Skipping.
# Processing Record 332 Of Set 332| viligili.
# City Not Found. Skipping.
# Processing Record 333 Of Set 333| Nakhon Thai.
# Processing Record 334 Of Set 334| Lethem.
# Processing Record 335 Of Set 335| Kijang.
# Processing Record 336 Of Set 336| Isiro.
# Processing Record 337 Of Set 337| olafsvik.
# City Not Found. Skipping.
# Processing Record 338 Of Set 338| Gawler.
# Processing Record 339 Of Set 339| Slonim.
# Processing Record 340 Of Set 340| vaitupu.
# City Not Found. Skipping.
# Processing Record 341 Of Set 341| Ginda.
# Processing Record 342 Of Set 342| Salalah.
# Processing Record 343 Of Set 343| Bilibino.
# Processing Record 344 Of Set 344| Berlevag.
# Processing Record 345 Of Set 345| Cuitlahuac.
# Processing Record 346 Of Set 346| Ulaangom.
# Processing Record 347 Of Set 347| Kamaishi.
# Processing Record 348 Of Set 348| Bukachacha.
# Processing Record 349 Of Set 349| Waitara.
# Processing Record 350 Of Set 350| Sibiti.
# Processing Record 351 Of Set 351| Esperance.
# Processing Record 352 Of Set 352| Hereford.
# Processing Record 353 Of Set 353| Warri.
# Processing Record 354 Of Set 354| Den Helder.
# Processing Record 355 Of Set 355| Slave Lake.
# Processing Record 356 Of Set 356| Aleksandrovskiy Zavod.
# Processing Record 357 Of Set 357| Leshukonskoye.
# Processing Record 358 Of Set 358| Yaring.
# Processing Record 359 Of Set 359| Victoria.
# Processing Record 360 Of Set 360| Kibala.
# Processing Record 361 Of Set 361| Hithadhoo.
# Processing Record 362 Of Set 362| Anzio.
# Processing Record 363 Of Set 363| Emerald.
# Processing Record 364 Of Set 364| Anadyr.
# Processing Record 365 Of Set 365| Ancud.
# Processing Record 366 Of Set 366| Gidam.
# Processing Record 367 Of Set 367| karkaralinsk.
# City Not Found. Skipping.
# Processing Record 368 Of Set 368| Namangan.
# Processing Record 369 Of Set 369| Ngunguru.
# Processing Record 370 Of Set 370| San Quintin.
# Processing Record 371 Of Set 371| Renqiu.
# Processing Record 372 Of Set 372| we.
# City Not Found. Skipping.
# Processing Record 373 Of Set 373| Buritizeiro.
# Processing Record 374 Of Set 374| Neiafu.
# Processing Record 375 Of Set 375| Mizdah.
# Processing Record 376 Of Set 376| bur gabo.
# City Not Found. Skipping.
# Processing Record 377 Of Set 377| khonuu.
# City Not Found. Skipping.
# Processing Record 378 Of Set 378| Odienne.
# Processing Record 379 Of Set 379| Mecca.
# Processing Record 380 Of Set 380| Saint-Joseph.
# Processing Record 381 Of Set 381| Sao Lourenco do Sul.
# Processing Record 382 Of Set 382| Benguela.
# Processing Record 383 Of Set 383| Zapolyarnyy.
# Processing Record 384 Of Set 384| Coquimbo.
# Processing Record 385 Of Set 385| North Miami Beach.
# Processing Record 386 Of Set 386| Beaufort.
# Processing Record 387 Of Set 387| Lima.
# Processing Record 388 Of Set 388| Hiriyur.
# Processing Record 389 Of Set 389| Auki.
# Processing Record 390 Of Set 390| Mnogovershinnyy.
# Processing Record 391 Of Set 391| Constitucion.
# Processing Record 392 Of Set 392| Catalina.
# Processing Record 393 Of Set 393| Acari.
# Processing Record 394 Of Set 394| Qalyub.
# Processing Record 395 Of Set 395| Mokhotlong.
# Processing Record 396 Of Set 396| Anshun.
# Processing Record 397 Of Set 397| Nola.
# Processing Record 398 Of Set 398| Waiuku.
# Processing Record 399 Of Set 399| Umm Lajj.
# Processing Record 400 Of Set 400| San Alberto.
# Processing Record 401 Of Set 401| Kenai.
# Processing Record 402 Of Set 402| Canutama.
# Processing Record 403 Of Set 403| Cabra.
# Processing Record 404 Of Set 404| Baie-Saint-Paul.
# Processing Record 405 Of Set 405| Abeche.
# Processing Record 406 Of Set 406| Port Macquarie.
# Processing Record 407 Of Set 407| Balikpapan.
# Processing Record 408 Of Set 408| Cedar City.
# Processing Record 409 Of Set 409| Noumea.
# Processing Record 410 Of Set 410| Vestmannaeyjar.
# Processing Record 411 Of Set 411| Papetoai.
# Processing Record 412 Of Set 412| Henties Bay.
# Processing Record 413 Of Set 413| Qaqortoq.
# Processing Record 414 Of Set 414| Najran.
# Processing Record 415 Of Set 415| tasbuget.
# City Not Found. Skipping.
# Processing Record 416 Of Set 416| kegayli.
# City Not Found. Skipping.
# Processing Record 417 Of Set 417| Rantepao.
# Processing Record 418 Of Set 418| cumaribo.
# City Not Found. Skipping.
# Processing Record 419 Of Set 419| Mananjary.
# Processing Record 420 Of Set 420| Turkmenabat.
# Processing Record 421 Of Set 421| Alizai.
# Processing Record 422 Of Set 422| Kirovohrad.
# Processing Record 423 Of Set 423| Vila do Maio.
# Processing Record 424 Of Set 424| Nagato.
# Processing Record 425 Of Set 425| paradwip.
# City Not Found. Skipping.
# Processing Record 426 Of Set 426| armacao dos buzios.
# City Not Found. Skipping.
# Processing Record 427 Of Set 427| Sakaiminato.
# Processing Record 428 Of Set 428| nam tha.
# City Not Found. Skipping.
# Processing Record 429 Of Set 429| Maputo.
# Processing Record 430 Of Set 430| Maceio.
# Processing Record 431 Of Set 431| Green River.
# Processing Record 432 Of Set 432| Mazagao.
# Processing Record 433 Of Set 433| Todos Santos.
# Processing Record 434 Of Set 434| raga.
# City Not Found. Skipping.
# Processing Record 435 Of Set 435| Pandan.
# Processing Record 436 Of Set 436| Deer Lake.
# Processing Record 437 Of Set 437| Mistrato.
# Processing Record 438 Of Set 438| Havre-Saint-Pierre.
# Processing Record 439 Of Set 439| Mbini.
# Processing Record 440 Of Set 440| Dhangadhi.
# Processing Record 441 Of Set 441| Ampanihy.
# Processing Record 442 Of Set 442| Bima.
# Processing Record 443 Of Set 443| Biak.
# Processing Record 444 Of Set 444| Catuday.
# Processing Record 445 Of Set 445| tawzar.
# City Not Found. Skipping.
# Processing Record 446 Of Set 446| Saint-Pierre.
# Processing Record 447 Of Set 447| Lavrentiya.
# Processing Record 448 Of Set 448| Hostotipaquillo.
# Processing Record 449 Of Set 449| Rzhyshchiv.
# Processing Record 450 Of Set 450| Talnakh.
# Processing Record 451 Of Set 451| sentyabrskiy.
# City Not Found. Skipping.
# Processing Record 452 Of Set 452| Arsk.
# Processing Record 453 Of Set 453| Beitbridge.
# Processing Record 454 Of Set 454| Derzhavinsk.
# Processing Record 455 Of Set 455| Bayji.
# Processing Record 456 Of Set 456| Mana.
# Processing Record 457 Of Set 457| Dreieich.
# Processing Record 458 Of Set 458| Pachino.
# Processing Record 459 Of Set 459| Bhadrachalam.
# Processing Record 460 Of Set 460| Angoram.
# Processing Record 461 Of Set 461| Aswan.
# Processing Record 462 Of Set 462| Cedar Rapids.
# Processing Record 463 Of Set 463| Bonfim.
# Processing Record 464 Of Set 464| Byron Bay.
# Processing Record 465 Of Set 465| Te Anau.
# Processing Record 466 Of Set 466| Okhotsk.
# Processing Record 467 Of Set 467| Umm Kaddadah.
# Processing Record 468 Of Set 468| Siparia.
# Processing Record 469 Of Set 469| Monteria.
# Processing Record 470 Of Set 470| San Andres.
# Processing Record 471 Of Set 471| Wesselsbron.
# Processing Record 472 Of Set 472| Sitangkai.
# Processing Record 473 Of Set 473| Mehamn.
# Processing Record 474 Of Set 474| Mangan.
# Processing Record 475 Of Set 475| Colac.
# Processing Record 476 Of Set 476| Les Trois-Ilets.
# Processing Record 477 Of Set 477| Basirhat.
# Processing Record 478 Of Set 478| Bara.
# Processing Record 479 Of Set 479| El Alto.
# Processing Record 480 Of Set 480| Sanchor.
# Processing Record 481 Of Set 481| Pangody.
# Processing Record 482 Of Set 482| asfi.
# City Not Found. Skipping.
# Processing Record 483 Of Set 483| Moose Factory.
# Processing Record 484 Of Set 484| Zhenlai.
# Processing Record 485 Of Set 485| Romny.
# Processing Record 486 Of Set 486| Korablino.
# Processing Record 487 Of Set 487| Ranong.
# Processing Record 488 Of Set 488| Kroya.
# Processing Record 489 Of Set 489| Tuatapere.
# Processing Record 490 Of Set 490| Gundorovskiy.
# Processing Record 491 Of Set 491| Valparaiso.
# Processing Record 492 Of Set 492| geylegphug.
# City Not Found. Skipping.
# Processing Record 493 Of Set 493| Richards Bay.
# Processing Record 494 Of Set 494| Yazman.
# Processing Record 495 Of Set 495| barawe.
# City Not Found. Skipping.
# Processing Record 496 Of Set 496| Souillac.
# Processing Record 497 Of Set 497| Miri.
# Processing Record 498 Of Set 498| La Rioja.
# Processing Record 499 Of Set 499| Katsuura.
# Processing Record 500 Of Set 500| Bow Island.
# Processing Record 501 Of Set 501| Muros.
# Processing Record 502 Of Set 502| tiruvottiyur.
# City Not Found. Skipping.
# Processing Record 503 Of Set 503| Mattru.
# Processing Record 504 Of Set 504| Omboue.
# Processing Record 505 Of Set 505| Carnot.
# Processing Record 506 Of Set 506| Hanmer Springs.
# Processing Record 507 Of Set 507| Baykit.
# Processing Record 508 Of Set 508| Roald.
# Processing Record 509 Of Set 509| Dickinson.
# Processing Record 510 Of Set 510| Shahgarh.
# Processing Record 511 Of Set 511| Pechory.
# Processing Record 512 Of Set 512| Chowchilla.
# Processing Record 513 Of Set 513| Poya.
# Processing Record 514 Of Set 514| Araouane.
# Processing Record 515 Of Set 515| barbar.
# City Not Found. Skipping.
# Processing Record 516 Of Set 516| Nyurba.
# Processing Record 517 Of Set 517| Weyburn.
# Processing Record 518 Of Set 518| saryshagan.
# City Not Found. Skipping.
# Processing Record 519 Of Set 519| Tanabe.
# Processing Record 520 Of Set 520| Yelizovo.
# Processing Record 521 Of Set 521| Frankenberg.
# Processing Record 522 Of Set 522| Whitianga.
# Processing Record 523 Of Set 523| Katobu.
# Processing Record 524 Of Set 524| Bo Phloi.
# Processing Record 525 Of Set 525| Santiago de Cao.
# Processing Record 526 Of Set 526| Hobyo.
# Processing Record 527 Of Set 527| Malinovoye Ozero.
# Processing Record 528 Of Set 528| Kushiro.
# Processing Record 529 Of Set 529| Merke.
# Processing Record 530 Of Set 530| Balkanabat.
# Processing Record 531 Of Set 531| urumqi.
# City Not Found. Skipping.
# Processing Record 532 Of Set 532| Linjiang.
# Processing Record 533 Of Set 533| Leningradskiy.
# Processing Record 534 Of Set 534| Kieta.
# Processing Record 535 Of Set 535| Kamenka.
# Processing Record 536 Of Set 536| Hastings.
# Processing Record 537 Of Set 537| Hudson Bay.
# Processing Record 538 Of Set 538| Taiyuan.
# Processing Record 539 Of Set 539| tres lagoas.
# City Not Found. Skipping.
# Processing Record 540 Of Set 540| Gimli.
# Processing Record 541 Of Set 541| Nantucket.
# Processing Record 542 Of Set 542| Kahului.
# Processing Record 543 Of Set 543| Olga.
# Processing Record 544 Of Set 544| Ewa Beach.
# Processing Record 545 Of Set 545| Lafiagi.
# Processing Record 546 Of Set 546| Half Moon Bay.
# Processing Record 547 Of Set 547| Uray.
# Processing Record 548 Of Set 548| Pangnirtung.
# Processing Record 549 Of Set 549| Labuhan.
# Processing Record 550 Of Set 550| Pallasovka.
# Processing Record 551 Of Set 551| Sinnamary.
# Processing Record 552 Of Set 552| Jackville.
# Processing Record 553 Of Set 553| Tchibanga.
# Processing Record 554 Of Set 554| Agadez.
# Processing Record 555 Of Set 555| Marawi.
# Processing Record 556 Of Set 556| Galle.
# Processing Record 557 Of Set 557| bokspits.
# City Not Found. Skipping.
# Processing Record 558 Of Set 558| Luang Prabang.
# Processing Record 559 Of Set 559| San Clemente.
# Processing Record 560 Of Set 560| Tromso.
# Processing Record 561 Of Set 561| Naumburg.
# Processing Record 562 Of Set 562| Villa Bruzual.
# Processing Record 563 Of Set 563| Dhidhdhoo.
# Processing Record 564 Of Set 564| Huilong.
# Processing Record 565 Of Set 565| Orsk.
# Processing Record 566 Of Set 566| Aitape.
# Processing Record 567 Of Set 567| Sept-Iles.
# Processing Record 568 Of Set 568| Kipushi.
# Processing Record 569 Of Set 569| Bukama.
# Processing Record 570 Of Set 570| Murgab.
# Processing Record 571 Of Set 571| Ustka.
# Processing Record 572 Of Set 572| katha.
# City Not Found. Skipping.
# Processing Record 573 Of Set 573| Northam.
# Processing Record 574 Of Set 574| Whitehorse.
# Processing Record 575 Of Set 575| Boende.
# Processing Record 576 Of Set 576| Abu Samrah.
# Processing Record 577 Of Set 577| Tizimin.
# Processing Record 578 Of Set 578| Mpika.
# Processing Record 579 Of Set 579| Juneau.
# Processing Record 580 Of Set 580| Voi.
# Processing Record 581 Of Set 581| Balkhash.
# Processing Record 582 Of Set 582| Bone.
# Processing Record 583 Of Set 583| Port Keats.
# Processing Record 584 Of Set 584| Jiuquan.
# Processing Record 585 Of Set 585| Medak.
# Processing Record 586 Of Set 586| Nianzishan.
# Processing Record 587 Of Set 587| Oranjemund.
# Processing Record 588 Of Set 588| Shahrud.
# Processing Record 589 Of Set 589| Kendari.
# Processing Record 590 Of Set 590| Pointe Michel.
# Processing Record 591 Of Set 591| yanchukan.
# City Not Found. Skipping.
# Processing Record 592 Of Set 592| Zemio.
# Processing Record 593 Of Set 593| Banamba.
# Processing Record 594 Of Set 594| Danilovka.
# Processing Record 595 Of Set 595| Lagoa.
# Processing Record 596 Of Set 596| Port Hawkesbury.
# Processing Record 597 Of Set 597| Chicama.
# Processing Record 598 Of Set 598| Tinos.
# Processing Record 599 Of Set 599| Santa Cruz.
# Processing Record 600 Of Set 600| Cacoal.
# Processing Record 601 Of Set 601| Cabadiangan.
# Processing Record 602 Of Set 602| Lasa.
# Processing Record 603 Of Set 603| Kalawit.
# Processing Record 604 Of Set 604| Batemans Bay.
# Processing Record 605 Of Set 605| Margate.
# Processing Record 606 Of Set 606| Verkhoshizhemye.
# Processing Record 607 Of Set 607| Ambilobe.
# Processing Record 608 Of Set 608| Tilichiki.
# Processing Record 609 Of Set 609| Lerwick.
# Processing Record 610 Of Set 610| Araioses.
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_data.dropna(inplace = True) 
print(cities_data)
# Out:
#                   City name Cloudiness Country    Lat     Lng        Date  \
# 0              Barreirinhas         99      BR  -2.75  -42.83  1569869530
# 1                 Alyangula          0      AU -13.85  136.42  1569869428
# 2                Bredasdorp         92      ZA -34.53   20.04  1569869284
# 3                   Rikitea         98      PF -23.12 -134.97  1569869531
# 4                  Saldanha          1      PT  41.42   -6.55  1569869531
# 5               barentsburg
# 6                     Bluff          0      AU -23.58  149.07  1569869531
# 7                 Busselton         91      AU -33.64  115.35  1569869532
# 8              Vangaindrano         10      MG -23.35    47.6  1569869532
# 9            Ribeira Grande         20      PT  38.52   -28.7  1569869532
# 10                    Alofi         90      NU -19.06 -169.92  1569869532
# 11                  Qaanaaq        100      GL  77.48  -69.36  1569869532
# 12                  Lusambo         51      CD  -4.97   23.44  1569869533
# 13                Kavaratti         96      IN  10.57   72.64  1569869533
# 14                  Gamboma        100      CG  -1.87   15.88  1569869533
# 15            Saint Anthony         90      US  43.97 -111.68  1569869533
# 16                    Avera          1      US  33.19  -82.53  1569869533
# 17               Hambantota         40      LK   6.12   81.12  1569869534
# 18                Upernavik         99      GL  72.79  -56.15  1569869534
# 19                   bargal
# 20   grand river south east
# 21              Tuktoyaktuk         75      CA  69.44 -133.03  1569869534
# 22                 Oxapampa         26      PE -10.58   -75.4  1569869534
# 23                  Ushtobe         45      KZ  45.25   77.98  1569869534
# 24                   Nemuro         45      JP  43.32  145.57  1569869535
# 25                 Acajutla          0      SV  13.59  -89.83  1569869268
# 26                Churapcha        100      RU     62  132.43  1569869535
# 27                  Ushuaia         75      AR -54.81  -68.31  1569869535
# 28              Port Alfred          3      ZA -33.59   26.89  1569869535
# 29                   Kodiak          1      US  39.95  -94.76  1569869536
# ..                      ...        ...     ...    ...     ...         ...
# 581                Balkhash         17      KZ  46.84   74.98  1569869642
# 582                    Bone          0      DE  51.97   12.14  1569869642
# 583              Port Keats          0      AU -14.25  129.55  1569869642
# 584                 Jiuquan          0      CN  39.73   98.49  1569869643
# 585                   Medak        100      IN  18.05   78.27  1569869643
# 586              Nianzishan         44      CN  47.51  122.88  1569869643
# 587              Oranjemund          0      ZA -28.55   16.43  1569869643
# 588                 Shahrud          1      IR  36.42   54.97  1569869643
# 589                 Kendari         52      ID  -3.99  122.52  1569869644
# 590           Pointe Michel         20      DM  15.25  -61.38  1569869644
# 591               yanchukan
# 592                   Zemio         85      CF   5.02   25.13  1569869644
# 593                 Banamba         35      ML  13.55   -7.45  1569869644
# 594               Danilovka         95      RU  50.35   44.12  1569869645
# 595                   Lagoa          0      PT  37.14   -8.45  1569869645
# 596         Port Hawkesbury         75      CA  45.62  -61.36  1569869645
# 597                 Chicama         75      PE  -7.84  -79.15  1569869645
# 598                   Tinos          0      GR  37.54   25.16  1569869645
# 599              Santa Cruz         93      BR  -6.22  -36.02  1569869540
# 600                  Cacoal         96      BR -11.43  -61.44  1569869646
# 601             Cabadiangan         75      PH  10.45  123.98  1569869646
# 602                    Lasa          0      CY  34.92   32.53  1569869646
# 603                 Kalawit        100      PH   7.91  122.53  1569869646
# 604            Batemans Bay         59      AU -35.71  150.18  1569869646
# 605                 Margate         25      AU -43.03  147.26  1569869434
# 606         Verkhoshizhemye        100      RU  58.01    49.1  1569869647
# 607                Ambilobe         17      MG -13.19   49.05  1569869647
# 608               Tilichiki        100      RU  60.47   166.1  1569869647
# 609                 Lerwick         40      GB  60.15   -1.15  1569869647
# 610                Araioses          0      BR  -2.89  -41.91  1569869647
#
#     Humidity Max temp Wind speed
# 0         45    92.52       8.59
# 1         93     66.2       3.36
# 2         76     53.6       5.82
# 3         72    69.12      15.28
# 4         47     74.7      12.62
# 5
# 6         29     66.6       9.95
# 7         72       54      12.41
# 8         97    70.02       3.83
# 9         69     73.4        4.7
# 10        94     73.4        4.7
# 11        76     34.2       8.59
# 12        85       72       0.67
# 13        75     80.1       3.04
# 14        89    70.92        3.2
# 15        53     42.8      12.75
# 16        37       97       6.93
# 17       100     75.2       3.36
# 18        63    40.14       4.99
# 19
# 20
# 21       100     39.2       5.82
# 22        88    63.36       4.63
# 23        58    46.08       8.28
# 24        91    61.92       7.87
# 25        58     87.8       3.36
# 26        98    33.84       3.36
# 27        86     33.8      13.87
# 28        84    60.01          4
# 29        62    87.01      14.99
# ..       ...      ...        ...
# 581       29    43.92       7.87
# 582       76    57.99      19.46
# 583       84    74.88       4.41
# 584       16    66.06       4.05
# 585       87    73.99       4.88
# 586       54       54       1.99
# 587       83     57.6      18.66
# 588       59    48.42       5.32
# 589       97    71.46       2.08
# 590       70     87.8       8.05
# 591
# 592       95     69.3       2.84
# 593       39    89.28       5.91
# 594       75    53.28      12.44
# 595       88    71.01       6.93
# 596       53    53.01      14.99
# 597       82     64.4      13.87
# 598       64       77       2.24
# 599       27     93.6      13.33
# 600       40    95.22       5.99
# 601       83     80.6       2.24
# 602       83     78.8       3.36
# 603       85    75.96       3.91
# 604       94       46       2.42
# 605       97       39       6.93
# 606       96    47.52      10.54
# 607       70    78.66      15.59
# 608       94    37.44       7.36
# 609       65     44.6      10.29
# 610       66       86      24.16
#
# [611 rows x 9 columns]

# %%
cities_data.count()
# Out:
# City name     611
# Cloudiness    611
# Country       611
# Lat           611
# Lng           611
# Date          611
# Humidity      611
# Max temp      611
# Wind speed    611
# dtype: int64

# %%
cities_data.head()
# Out:
#       City name Cloudiness Country    Lat     Lng        Date Humidity  \
# 0  Barreirinhas         99      BR  -2.75  -42.83  1569869530       45
# 1     Alyangula          0      AU -13.85  136.42  1569869428       93
# 2    Bredasdorp         92      ZA -34.53   20.04  1569869284       76
# 3       Rikitea         98      PF -23.12 -134.97  1569869531       72
# 4      Saldanha          1      PT  41.42   -6.55  1569869531       47
#
#   Max temp Wind speed
# 0    92.52       8.59
# 1     66.2       3.36
# 2     53.6       5.82
# 3    69.12      15.28
# 4     74.7      12.62

# %%
cities_data = cities_data.convert_objects(convert_numeric=True)
cities_data.dtypes
# Out:
# /Users/adeliamanuel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# City name      object
# Cloudiness    float64
# Country        object
# Lat           float64
# Lng           float64
# Date          float64
# Humidity      float64
# Max temp      float64
# Wind speed    float64
# dtype: object

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Max temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Max Temperature Plot(09/30/19)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatitudeVSTemperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Humidity"], marker="o",s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity Plot(09/30/19)")
plt.ylabel("Latitude")
plt.xlabel("Humidity")
plt.grid(True)

# Save the figure
plt.savefig("LatitudevsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Cloudiness"], marker="o",s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness(09/30/19)")
plt.ylabel("Latitude")
plt.xlabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("LatitudevsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Wind speed"], marker="o",s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed(09/30/19)")
plt.ylabel("Latitude")
plt.xlabel("Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("LatitudevsWindSpeed.png")

# Show plot
plt.show()
