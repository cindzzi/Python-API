# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="  
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=134666dd0e2cc872e1f9ae630e853b34&units=Imperial&q='

# %%
# Add columns for lat, cloudiness, country, temp, date, humidity, lng, max temp, wind speed
cities_data=pd.DataFrame(cities)
cities_data['Cloudiness']=""
cities_data['Country']=""
cities_data['Lat']=""
cities_data['Lng']=" "
cities_data['Date']=""
cities_data['Humidity']=""
cities_data['Max temp']=""
cities_data['Wind speed']=""

cities_data = cities_data.rename(columns={0: "City name"})

# %%
print("Beginning Data Complete")
print("-------------------------")

# use iterrows to iterate through pandas dataframe
for index, row in cities_data.iterrows():
    city = row['City name']
    
    response = requests.get(query_url + city).json()
    
    try:
        
        print(f"Processing Record {index} Of Set {index}| {city}.")
        
        cities_data.loc[index,'City name'] = response ['name']
        cities_data.loc[index,'Cloudiness'] = response ['clouds']['all']
        cities_data.loc[index,'Country'] = response ['sys']['country']
        cities_data.loc[index,'Lat'] = response ['coord']['lat']
        cities_data.loc[index,'Lng'] = response ['coord']['lon']
        cities_data.loc[index,'Date'] = response ['dt']
        cities_data.loc[index,'Humidity'] = response ['main']['humidity']
        cities_data.loc[index,'Max temp'] = response ['main']['temp_max']
        cities_data.loc[index,'Wind speed'] = response ['wind']['speed']
        

    except (KeyError, IndexError):
        print("City Not Found. Skipping.")
        
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Complete
# -------------------------
# Processing Record 0 Of Set 0| gamba.
# Processing Record 1 Of Set 1| tumannyy.
# City Not Found. Skipping.
# Processing Record 2 Of Set 2| kolyvan.
# Processing Record 3 Of Set 3| hasaki.
# Processing Record 4 Of Set 4| airai.
# Processing Record 5 Of Set 5| nichinan.
# Processing Record 6 Of Set 6| nome.
# Processing Record 7 Of Set 7| dalhousie.
# Processing Record 8 Of Set 8| broome.
# Processing Record 9 Of Set 9| samagaltay.
# Processing Record 10 Of Set 10| cape town.
# Processing Record 11 Of Set 11| sitka.
# Processing Record 12 Of Set 12| new norfolk.
# Processing Record 13 Of Set 13| gliwice.
# Processing Record 14 Of Set 14| vostok.
# Processing Record 15 Of Set 15| saint george.
# Processing Record 16 Of Set 16| filadelfia.
# Processing Record 17 Of Set 17| mount isa.
# Processing Record 18 Of Set 18| yellowknife.
# Processing Record 19 Of Set 19| alofi.
# Processing Record 20 Of Set 20| grand river south east.
# City Not Found. Skipping.
# Processing Record 21 Of Set 21| constitucion.
# Processing Record 22 Of Set 22| hue.
# Processing Record 23 Of Set 23| tasiilaq.
# Processing Record 24 Of Set 24| lompoc.
# Processing Record 25 Of Set 25| avarua.
# Processing Record 26 Of Set 26| thinadhoo.
# Processing Record 27 Of Set 27| chokurdakh.
# Processing Record 28 Of Set 28| bluff.
# Processing Record 29 Of Set 29| hermanus.
# Processing Record 30 Of Set 30| kingsport.
# Processing Record 31 Of Set 31| zhumadian.
# Processing Record 32 Of Set 32| mansehra.
# Processing Record 33 Of Set 33| bengkulu.
# City Not Found. Skipping.
# Processing Record 34 Of Set 34| busselton.
# Processing Record 35 Of Set 35| abdanan.
# Processing Record 36 Of Set 36| illoqqortoormiut.
# City Not Found. Skipping.
# Processing Record 37 Of Set 37| nenjiang.
# Processing Record 38 Of Set 38| meulaboh.
# Processing Record 39 Of Set 39| southbridge.
# Processing Record 40 Of Set 40| hofn.
# Processing Record 41 Of Set 41| dingle.
# Processing Record 42 Of Set 42| dehloran.
# Processing Record 43 Of Set 43| mareeba.
# Processing Record 44 Of Set 44| marcona.
# City Not Found. Skipping.
# Processing Record 45 Of Set 45| socorro.
# Processing Record 46 Of Set 46| upernavik.
# Processing Record 47 Of Set 47| katsuura.
# Processing Record 48 Of Set 48| portland.
# Processing Record 49 Of Set 49| tuktoyaktuk.
# Processing Record 50 Of Set 50| albany.
# Processing Record 51 Of Set 51| calvinia.
# Processing Record 52 Of Set 52| caravelas.
# Processing Record 53 Of Set 53| ushuaia.
# Processing Record 54 Of Set 54| jamestown.
# Processing Record 55 Of Set 55| port lincoln.
# Processing Record 56 Of Set 56| marion.
# Processing Record 57 Of Set 57| miri.
# Processing Record 58 Of Set 58| attawapiskat.
# City Not Found. Skipping.
# Processing Record 59 Of Set 59| dakar.
# Processing Record 60 Of Set 60| flinders.
# Processing Record 61 Of Set 61| batemans bay.
# Processing Record 62 Of Set 62| san juan bautista.
# Processing Record 63 Of Set 63| kodiak.
# Processing Record 64 Of Set 64| rio gallegos.
# Processing Record 65 Of Set 65| mataura.
# Processing Record 66 Of Set 66| sorland.
# Processing Record 67 Of Set 67| geraldton.
# Processing Record 68 Of Set 68| pilar.
# Processing Record 69 Of Set 69| talnakh.
# Processing Record 70 Of Set 70| bulgan.
# Processing Record 71 Of Set 71| barrow.
# Processing Record 72 Of Set 72| hovd.
# Processing Record 73 Of Set 73| rikitea.
# Processing Record 74 Of Set 74| kalmunai.
# Processing Record 75 Of Set 75| cherskiy.
# Processing Record 76 Of Set 76| carnarvon.
# Processing Record 77 Of Set 77| neiafu.
# Processing Record 78 Of Set 78| norman wells.
# Processing Record 79 Of Set 79| kamenka.
# Processing Record 80 Of Set 80| monrovia.
# Processing Record 81 Of Set 81| east london.
# Processing Record 82 Of Set 82| hilo.
# Processing Record 83 Of Set 83| port macquarie.
# Processing Record 84 Of Set 84| saint combs.
# City Not Found. Skipping.
# Processing Record 85 Of Set 85| ixtapa.
# Processing Record 86 Of Set 86| clyde river.
# Processing Record 87 Of Set 87| kralendijk.
# Processing Record 88 Of Set 88| erenhot.
# Processing Record 89 Of Set 89| atuona.
# Processing Record 90 Of Set 90| kapchorwa.
# Processing Record 91 Of Set 91| wyndham.
# Processing Record 92 Of Set 92| markala.
# Processing Record 93 Of Set 93| port hardy.
# Processing Record 94 Of Set 94| margate.
# Processing Record 95 Of Set 95| vilhena.
# Processing Record 96 Of Set 96| gurupi.
# Processing Record 97 Of Set 97| paita.
# Processing Record 98 Of Set 98| charters towers.
# Processing Record 99 Of Set 99| togur.
# Processing Record 100 Of Set 100| mayumba.
# Processing Record 101 Of Set 101| namibe.
# Processing Record 102 Of Set 102| meridian.
# Processing Record 103 Of Set 103| barentsburg.
# City Not Found. Skipping.
# Processing Record 104 Of Set 104| mahebourg.
# Processing Record 105 Of Set 105| vao.
# Processing Record 106 Of Set 106| agadez.
# Processing Record 107 Of Set 107| kapaa.
# Processing Record 108 Of Set 108| leh.
# Processing Record 109 Of Set 109| isangel.
# Processing Record 110 Of Set 110| samusu.
# City Not Found. Skipping.
# Processing Record 111 Of Set 111| luderitz.
# Processing Record 112 Of Set 112| bolungarvik.
# City Not Found. Skipping.
# Processing Record 113 Of Set 113| parasia.
# Processing Record 114 Of Set 114| hami.
# Processing Record 115 Of Set 115| muvattupula.
# Processing Record 116 Of Set 116| chapais.
# Processing Record 117 Of Set 117| kattivakkam.
# Processing Record 118 Of Set 118| lavrentiya.
# Processing Record 119 Of Set 119| tsuyama.
# Processing Record 120 Of Set 120| diffa.
# Processing Record 121 Of Set 121| ambon.
# Processing Record 122 Of Set 122| general pico.
# Processing Record 123 Of Set 123| saleaula.
# City Not Found. Skipping.
# Processing Record 124 Of Set 124| nitchidorf.
# Processing Record 125 Of Set 125| saint-pierre.
# Processing Record 126 Of Set 126| coatesville.
# Processing Record 127 Of Set 127| paso de los toros.
# Processing Record 128 Of Set 128| belushya guba.
# City Not Found. Skipping.
# Processing Record 129 Of Set 129| sterling.
# Processing Record 130 Of Set 130| tuatapere.
# Processing Record 131 Of Set 131| teacapan.
# Processing Record 132 Of Set 132| tiksi.
# Processing Record 133 Of Set 133| qaanaaq.
# Processing Record 134 Of Set 134| baiyin.
# Processing Record 135 Of Set 135| jinchengjiang.
# City Not Found. Skipping.
# Processing Record 136 Of Set 136| yulara.
# Processing Record 137 Of Set 137| khatanga.
# Processing Record 138 Of Set 138| atar.
# Processing Record 139 Of Set 139| rungata.
# City Not Found. Skipping.
# Processing Record 140 Of Set 140| ca mau.
# Processing Record 141 Of Set 141| kamenskoye.
# City Not Found. Skipping.
# Processing Record 142 Of Set 142| bethel.
# Processing Record 143 Of Set 143| lagoa.
# Processing Record 144 Of Set 144| zabolotovka.
# Processing Record 145 Of Set 145| amderma.
# City Not Found. Skipping.
# Processing Record 146 Of Set 146| karratha.
# Processing Record 147 Of Set 147| grafton.
# Processing Record 148 Of Set 148| tilichiki.
# Processing Record 149 Of Set 149| dukat.
# Processing Record 150 Of Set 150| hobart.
# Processing Record 151 Of Set 151| hithadhoo.
# Processing Record 152 Of Set 152| port shepstone.
# Processing Record 153 Of Set 153| yarmouth.
# Processing Record 154 Of Set 154| fort nelson.
# Processing Record 155 Of Set 155| port hedland.
# Processing Record 156 Of Set 156| san cristobal.
# Processing Record 157 Of Set 157| cabra.
# Processing Record 158 Of Set 158| taolanaro.
# City Not Found. Skipping.
# Processing Record 159 Of Set 159| rio claro.
# Processing Record 160 Of Set 160| redcliffe.
# Processing Record 161 Of Set 161| pevek.
# Processing Record 162 Of Set 162| javier.
# Processing Record 163 Of Set 163| sale.
# Processing Record 164 Of Set 164| leningradskiy.
# Processing Record 165 Of Set 165| acapulco.
# Processing Record 166 Of Set 166| barao de melgaco.
# Processing Record 167 Of Set 167| thai nguyen.
# Processing Record 168 Of Set 168| lichuan.
# Processing Record 169 Of Set 169| punta arenas.
# Processing Record 170 Of Set 170| bereda.
# Processing Record 171 Of Set 171| labuhan.
# Processing Record 172 Of Set 172| puerto ayora.
# Processing Record 173 Of Set 173| san patricio.
# Processing Record 174 Of Set 174| tual.
# Processing Record 175 Of Set 175| oxford.
# Processing Record 176 Of Set 176| victoria.
# Processing Record 177 Of Set 177| sao joao da barra.
# Processing Record 178 Of Set 178| chuy.
# Processing Record 179 Of Set 179| olafsvik.
# City Not Found. Skipping.
# Processing Record 180 Of Set 180| surt.
# Processing Record 181 Of Set 181| tsihombe.
# City Not Found. Skipping.
# Processing Record 182 Of Set 182| sentyabrskiy.
# City Not Found. Skipping.
# Processing Record 183 Of Set 183| bonavista.
# Processing Record 184 Of Set 184| sydney.
# Processing Record 185 Of Set 185| butaritari.
# Processing Record 186 Of Set 186| sinnamary.
# Processing Record 187 Of Set 187| gari.
# Processing Record 188 Of Set 188| puerto escondido.
# Processing Record 189 Of Set 189| georgetown.
# Processing Record 190 Of Set 190| necochea.
# Processing Record 191 Of Set 191| iqaluit.
# Processing Record 192 Of Set 192| fairview.
# Processing Record 193 Of Set 193| dunedin.
# Processing Record 194 Of Set 194| rio grande.
# Processing Record 195 Of Set 195| lebu.
# Processing Record 196 Of Set 196| palabuhanratu.
# City Not Found. Skipping.
# Processing Record 197 Of Set 197| ahuimanu.
# Processing Record 198 Of Set 198| castro.
# Processing Record 199 Of Set 199| odweyne.
# City Not Found. Skipping.
# Processing Record 200 Of Set 200| goderich.
# Processing Record 201 Of Set 201| riohacha.
# Processing Record 202 Of Set 202| byron bay.
# Processing Record 203 Of Set 203| sirohi.
# Processing Record 204 Of Set 204| olden.
# Processing Record 205 Of Set 205| evensk.
# Processing Record 206 Of Set 206| cayenne.
# Processing Record 207 Of Set 207| ponta do sol.
# Processing Record 208 Of Set 208| cidreira.
# Processing Record 209 Of Set 209| terme.
# Processing Record 210 Of Set 210| chivay.
# Processing Record 211 Of Set 211| namatanai.
# Processing Record 212 Of Set 212| havre-saint-pierre.
# Processing Record 213 Of Set 213| coxim.
# Processing Record 214 Of Set 214| saryagash.
# Processing Record 215 Of Set 215| mathathane.
# Processing Record 216 Of Set 216| salym.
# Processing Record 217 Of Set 217| saint-philippe.
# Processing Record 218 Of Set 218| the valley.
# Processing Record 219 Of Set 219| port alfred.
# Processing Record 220 Of Set 220| bredasdorp.
# Processing Record 221 Of Set 221| kaitangata.
# Processing Record 222 Of Set 222| ilulissat.
# Processing Record 223 Of Set 223| palembang.
# Processing Record 224 Of Set 224| rawannawi.
# City Not Found. Skipping.
# Processing Record 225 Of Set 225| cururupu.
# Processing Record 226 Of Set 226| ahumada.
# City Not Found. Skipping.
# Processing Record 227 Of Set 227| arman.
# Processing Record 228 Of Set 228| verkhoyansk.
# Processing Record 229 Of Set 229| fortuna.
# Processing Record 230 Of Set 230| mar del plata.
# Processing Record 231 Of Set 231| aflu.
# City Not Found. Skipping.
# Processing Record 232 Of Set 232| poronaysk.
# Processing Record 233 Of Set 233| atambua.
# Processing Record 234 Of Set 234| ngunguru.
# Processing Record 235 Of Set 235| souillac.
# Processing Record 236 Of Set 236| plettenberg bay.
# Processing Record 237 Of Set 237| nikolskoye.
# Processing Record 238 Of Set 238| babylon.
# Processing Record 239 Of Set 239| sisimiut.
# Processing Record 240 Of Set 240| pareora.
# Processing Record 241 Of Set 241| kuching.
# Processing Record 242 Of Set 242| west wendover.
# Processing Record 243 Of Set 243| datong.
# Processing Record 244 Of Set 244| we.
# City Not Found. Skipping.
# Processing Record 245 Of Set 245| bambous virieux.
# Processing Record 246 Of Set 246| martapura.
# Processing Record 247 Of Set 247| tanete.
# Processing Record 248 Of Set 248| te anau.
# Processing Record 249 Of Set 249| assomada.
# Processing Record 250 Of Set 250| san-pedro.
# Processing Record 251 Of Set 251| nuuk.
# Processing Record 252 Of Set 252| kalawit.
# Processing Record 253 Of Set 253| general roca.
# Processing Record 254 Of Set 254| presidencia roque saenz pena.
# Processing Record 255 Of Set 255| bela.
# Processing Record 256 Of Set 256| vaini.
# Processing Record 257 Of Set 257| palu.
# Processing Record 258 Of Set 258| tadine.
# Processing Record 259 Of Set 259| sao filipe.
# Processing Record 260 Of Set 260| yar-sale.
# Processing Record 261 Of Set 261| tumalaytay.
# Processing Record 262 Of Set 262| maarianhamina.
# City Not Found. Skipping.
# Processing Record 263 Of Set 263| kalabo.
# Processing Record 264 Of Set 264| kropotkin.
# Processing Record 265 Of Set 265| gizo.
# Processing Record 266 Of Set 266| ribeira grande.
# Processing Record 267 Of Set 267| gerash.
# Processing Record 268 Of Set 268| valparaiso.
# Processing Record 269 Of Set 269| aksarka.
# Processing Record 270 Of Set 270| remedios.
# Processing Record 271 Of Set 271| kushmurun.
# City Not Found. Skipping.
# Processing Record 272 Of Set 272| jizan.
# Processing Record 273 Of Set 273| itarema.
# Processing Record 274 Of Set 274| aberdeen.
# Processing Record 275 Of Set 275| half moon bay.
# Processing Record 276 Of Set 276| maragogi.
# Processing Record 277 Of Set 277| narsaq.
# Processing Record 278 Of Set 278| quatre cocos.
# Processing Record 279 Of Set 279| hereford.
# Processing Record 280 Of Set 280| maniitsoq.
# Processing Record 281 Of Set 281| padang.
# Processing Record 282 Of Set 282| gulabpura.
# Processing Record 283 Of Set 283| ban nahin.
# Processing Record 284 Of Set 284| asosa.
# Processing Record 285 Of Set 285| tautira.
# Processing Record 286 Of Set 286| manokwari.
# Processing Record 287 Of Set 287| longyearbyen.
# Processing Record 288 Of Set 288| cap malheureux.
# Processing Record 289 Of Set 289| seydi.
# Processing Record 290 Of Set 290| lufilufi.
# Processing Record 291 Of Set 291| dvinskoy.
# Processing Record 292 Of Set 292| yelizovo.
# Processing Record 293 Of Set 293| arraial do cabo.
# Processing Record 294 Of Set 294| boddam.
# Processing Record 295 Of Set 295| shushtar.
# Processing Record 296 Of Set 296| meadow lake.
# Processing Record 297 Of Set 297| kulu.
# Processing Record 298 Of Set 298| chuzhou.
# Processing Record 299 Of Set 299| maryborough.
# Processing Record 300 Of Set 300| faanui.
# Processing Record 301 Of Set 301| bathsheba.
# Processing Record 302 Of Set 302| mys shmidta.
# City Not Found. Skipping.
# Processing Record 303 Of Set 303| martyush.
# Processing Record 304 Of Set 304| la asuncion.
# Processing Record 305 Of Set 305| balkhash.
# Processing Record 306 Of Set 306| leshukonskoye.
# Processing Record 307 Of Set 307| port blair.
# Processing Record 308 Of Set 308| port-gentil.
# Processing Record 309 Of Set 309| ancud.
# Processing Record 310 Of Set 310| selimpasa.
# Processing Record 311 Of Set 311| ucluelet.
# Processing Record 312 Of Set 312| pangnirtung.
# Processing Record 313 Of Set 313| kavieng.
# Processing Record 314 Of Set 314| guerrero negro.
# Processing Record 315 Of Set 315| monroe.
# Processing Record 316 Of Set 316| xining.
# Processing Record 317 Of Set 317| sikea.
# City Not Found. Skipping.
# Processing Record 318 Of Set 318| bilma.
# Processing Record 319 Of Set 319| kruisfontein.
# Processing Record 320 Of Set 320| cam pha.
# City Not Found. Skipping.
# Processing Record 321 Of Set 321| almeria.
# Processing Record 322 Of Set 322| bandundu.
# Processing Record 323 Of Set 323| mulatupo.
# City Not Found. Skipping.
# Processing Record 324 Of Set 324| provideniya.
# Processing Record 325 Of Set 325| lorengau.
# Processing Record 326 Of Set 326| tasbuget.
# City Not Found. Skipping.
# Processing Record 327 Of Set 327| balod.
# Processing Record 328 Of Set 328| oranjestad.
# Processing Record 329 Of Set 329| qandala.
# Processing Record 330 Of Set 330| bitung.
# Processing Record 331 Of Set 331| ningan.
# City Not Found. Skipping.
# Processing Record 332 Of Set 332| nyurba.
# Processing Record 333 Of Set 333| butwal.
# Processing Record 334 Of Set 334| soledade.
# Processing Record 335 Of Set 335| rayong.
# Processing Record 336 Of Set 336| vila velha.
# Processing Record 337 Of Set 337| fecamp.
# Processing Record 338 Of Set 338| palmer.
# Processing Record 339 Of Set 339| oranjemund.
# Processing Record 340 Of Set 340| taoudenni.
# Processing Record 341 Of Set 341| yuli.
# Processing Record 342 Of Set 342| ratnagiri.
# Processing Record 343 Of Set 343| klaksvik.
# Processing Record 344 Of Set 344| kaitong.
# Processing Record 345 Of Set 345| chicama.
# Processing Record 346 Of Set 346| malinovoye ozero.
# Processing Record 347 Of Set 347| zachagansk.
# City Not Found. Skipping.
# Processing Record 348 Of Set 348| lata.
# Processing Record 349 Of Set 349| thompson.
# Processing Record 350 Of Set 350| sanchor.
# Processing Record 351 Of Set 351| ternate.
# Processing Record 352 Of Set 352| constantine.
# Processing Record 353 Of Set 353| ardistan.
# City Not Found. Skipping.
# Processing Record 354 Of Set 354| grindavik.
# Processing Record 355 Of Set 355| yarada.
# Processing Record 356 Of Set 356| mount pleasant.
# Processing Record 357 Of Set 357| maracas.
# Processing Record 358 Of Set 358| codrington.
# Processing Record 359 Of Set 359| oussouye.
# Processing Record 360 Of Set 360| college.
# Processing Record 361 Of Set 361| pitanga.
# Processing Record 362 Of Set 362| stokmarknes.
# Processing Record 363 Of Set 363| ongandjera.
# Processing Record 364 Of Set 364| torbay.
# Processing Record 365 Of Set 365| srednekolymsk.
# Processing Record 366 Of Set 366| wageningen.
# Processing Record 367 Of Set 367| ambilobe.
# Processing Record 368 Of Set 368| sorong.
# Processing Record 369 Of Set 369| ambodifototra.
# City Not Found. Skipping.
# Processing Record 370 Of Set 370| nong bua.
# Processing Record 371 Of Set 371| port elizabeth.
# Processing Record 372 Of Set 372| xiongzhou.
# Processing Record 373 Of Set 373| springbok.
# Processing Record 374 Of Set 374| ati.
# Processing Record 375 Of Set 375| jalu.
# Processing Record 376 Of Set 376| labrea.
# City Not Found. Skipping.
# Processing Record 377 Of Set 377| vadso.
# Processing Record 378 Of Set 378| pochutla.
# Processing Record 379 Of Set 379| dikson.
# Processing Record 380 Of Set 380| ilmajoki.
# Processing Record 381 Of Set 381| puerto carreno.
# Processing Record 382 Of Set 382| ulaanbaatar.
# Processing Record 383 Of Set 383| beyneu.
# Processing Record 384 Of Set 384| meyungs.
# City Not Found. Skipping.
# Processing Record 385 Of Set 385| tutayev.
# Processing Record 386 Of Set 386| jaslo.
# Processing Record 387 Of Set 387| dolores.
# Processing Record 388 Of Set 388| sukpak.
# Processing Record 389 Of Set 389| saskylakh.
# Processing Record 390 Of Set 390| ipixuna.
# Processing Record 391 Of Set 391| milkovo.
# Processing Record 392 Of Set 392| frutal.
# Processing Record 393 Of Set 393| amapa.
# Processing Record 394 Of Set 394| hambantota.
# Processing Record 395 Of Set 395| dezhou.
# Processing Record 396 Of Set 396| san miguelito.
# Processing Record 397 Of Set 397| caarapo.
# Processing Record 398 Of Set 398| burica.
# City Not Found. Skipping.
# Processing Record 399 Of Set 399| mananjary.
# Processing Record 400 Of Set 400| virginia beach.
# Processing Record 401 Of Set 401| jiroft.
# City Not Found. Skipping.
# Processing Record 402 Of Set 402| san vicente.
# Processing Record 403 Of Set 403| klyuchevskiy.
# Processing Record 404 Of Set 404| bandarbeyla.
# Processing Record 405 Of Set 405| los llanos de aridane.
# Processing Record 406 Of Set 406| tommot.
# Processing Record 407 Of Set 407| nanortalik.
# Processing Record 408 Of Set 408| gautier.
# Processing Record 409 Of Set 409| mokhsogollokh.
# Processing Record 410 Of Set 410| sal rei.
# Processing Record 411 Of Set 411| tuggurt.
# City Not Found. Skipping.
# Processing Record 412 Of Set 412| canar.
# Processing Record 413 Of Set 413| bojonegoro.
# Processing Record 414 Of Set 414| batagay.
# Processing Record 415 Of Set 415| ranong.
# Processing Record 416 Of Set 416| ierapetra.
# Processing Record 417 Of Set 417| santa rosalia.
# Processing Record 418 Of Set 418| coralville.
# Processing Record 419 Of Set 419| asfi.
# City Not Found. Skipping.
# Processing Record 420 Of Set 420| coos bay.
# Processing Record 421 Of Set 421| progreso.
# Processing Record 422 Of Set 422| toliary.
# City Not Found. Skipping.
# Processing Record 423 Of Set 423| awbari.
# Processing Record 424 Of Set 424| pingdingshan.
# Processing Record 425 Of Set 425| correia pinto.
# Processing Record 426 Of Set 426| teluknaga.
# Processing Record 427 Of Set 427| north vanlaiphai.
# Processing Record 428 Of Set 428| sao felix do xingu.
# Processing Record 429 Of Set 429| yemtsa.
# Processing Record 430 Of Set 430| plouzane.
# Processing Record 431 Of Set 431| moree.
# Processing Record 432 Of Set 432| warqla.
# City Not Found. Skipping.
# Processing Record 433 Of Set 433| hauterive.
# Processing Record 434 Of Set 434| mizan teferi.
# Processing Record 435 Of Set 435| oktyabrskoye.
# Processing Record 436 Of Set 436| nguiu.
# City Not Found. Skipping.
# Processing Record 437 Of Set 437| whitianga.
# Processing Record 438 Of Set 438| mwense.
# Processing Record 439 Of Set 439| vila franca do campo.
# Processing Record 440 Of Set 440| yuma.
# Processing Record 441 Of Set 441| cabo san lucas.
# Processing Record 442 Of Set 442| formoso do araguaia.
# City Not Found. Skipping.
# Processing Record 443 Of Set 443| nizhneyansk.
# City Not Found. Skipping.
# Processing Record 444 Of Set 444| san carlos.
# Processing Record 445 Of Set 445| hay river.
# Processing Record 446 Of Set 446| vaitupu.
# City Not Found. Skipping.
# Processing Record 447 Of Set 447| esperance.
# Processing Record 448 Of Set 448| georgiyevka.
# Processing Record 449 Of Set 449| luangwa.
# Processing Record 450 Of Set 450| pimentel.
# Processing Record 451 Of Set 451| saldanha.
# Processing Record 452 Of Set 452| buala.
# Processing Record 453 Of Set 453| bundaberg.
# Processing Record 454 Of Set 454| tazovskiy.
# Processing Record 455 Of Set 455| san policarpo.
# Processing Record 456 Of Set 456| hushitai.
# Processing Record 457 Of Set 457| shar.
# Processing Record 458 Of Set 458| novokayakent.
# Processing Record 459 Of Set 459| asau.
# City Not Found. Skipping.
# Processing Record 460 Of Set 460| kushima.
# Processing Record 461 Of Set 461| pampa.
# Processing Record 462 Of Set 462| burnie.
# Processing Record 463 Of Set 463| naugarzan.
# City Not Found. Skipping.
# Processing Record 464 Of Set 464| nechi.
# Processing Record 465 Of Set 465| petropavlovsk-kamchatskiy.
# Processing Record 466 Of Set 466| lakhipur.
# Processing Record 467 Of Set 467| benghazi.
# Processing Record 468 Of Set 468| stromness.
# Processing Record 469 Of Set 469| saint-augustin.
# Processing Record 470 Of Set 470| zlobin.
# Processing Record 471 Of Set 471| wau.
# City Not Found. Skipping.
# Processing Record 472 Of Set 472| krasnoye.
# Processing Record 473 Of Set 473| sibolga.
# Processing Record 474 Of Set 474| nizhneivkino.
# Processing Record 475 Of Set 475| kusatsu.
# Processing Record 476 Of Set 476| saint anthony.
# Processing Record 477 Of Set 477| vuktyl.
# Processing Record 478 Of Set 478| dubti.
# Processing Record 479 Of Set 479| cosala.
# City Not Found. Skipping.
# Processing Record 480 Of Set 480| karaul.
# City Not Found. Skipping.
# Processing Record 481 Of Set 481| vada.
# Processing Record 482 Of Set 482| boden.
# Processing Record 483 Of Set 483| narbonne.
# Processing Record 484 Of Set 484| dzilam gonzalez.
# Processing Record 485 Of Set 485| banepa.
# Processing Record 486 Of Set 486| pacific grove.
# Processing Record 487 Of Set 487| mackay.
# Processing Record 488 Of Set 488| tabou.
# Processing Record 489 Of Set 489| jiangyou.
# Processing Record 490 Of Set 490| san quintin.
# Processing Record 491 Of Set 491| konigslutter.
# City Not Found. Skipping.
# Processing Record 492 Of Set 492| teguldet.
# Processing Record 493 Of Set 493| coquimbo.
# Processing Record 494 Of Set 494| hajnowka.
# Processing Record 495 Of Set 495| atasu.
# Processing Record 496 Of Set 496| aizpute.
# Processing Record 497 Of Set 497| sarahan.
# Processing Record 498 Of Set 498| joutseno.
# Processing Record 499 Of Set 499| kargasok.
# Processing Record 500 Of Set 500| kahului.
# Processing Record 501 Of Set 501| uvat.
# Processing Record 502 Of Set 502| bargal.
# City Not Found. Skipping.
# Processing Record 503 Of Set 503| yamethin.
# Processing Record 504 Of Set 504| vilyuysk.
# Processing Record 505 Of Set 505| mocambique.
# City Not Found. Skipping.
# Processing Record 506 Of Set 506| vagur.
# Processing Record 507 Of Set 507| pisco.
# Processing Record 508 Of Set 508| boundiali.
# Processing Record 509 Of Set 509| bradesti.
# Processing Record 510 Of Set 510| luena.
# Processing Record 511 Of Set 511| korla.
# City Not Found. Skipping.
# Processing Record 512 Of Set 512| nandigama.
# Processing Record 513 Of Set 513| nelson bay.
# Processing Record 514 Of Set 514| severo-kurilsk.
# Processing Record 515 Of Set 515| thunder bay.
# Processing Record 516 Of Set 516| armacao dos buzios.
# City Not Found. Skipping.
# Processing Record 517 Of Set 517| aklavik.
# Processing Record 518 Of Set 518| vytegra.
# Processing Record 519 Of Set 519| iberia.
# Processing Record 520 Of Set 520| ouadda.
# Processing Record 521 Of Set 521| novyy nekouz.
# Processing Record 522 Of Set 522| lysva.
# Processing Record 523 Of Set 523| santa maria.
# Processing Record 524 Of Set 524| sebring.
# Processing Record 525 Of Set 525| nsanje.
# Processing Record 526 Of Set 526| takoradi.
# Processing Record 527 Of Set 527| banda aceh.
# Processing Record 528 Of Set 528| walvis bay.
# Processing Record 529 Of Set 529| itapirapua.
# Processing Record 530 Of Set 530| pahrump.
# Processing Record 531 Of Set 531| yerbogachen.
# Processing Record 532 Of Set 532| bara.
# Processing Record 533 Of Set 533| weinan.
# Processing Record 534 Of Set 534| el vendrell.
# Processing Record 535 Of Set 535| tidore.
# City Not Found. Skipping.
# Processing Record 536 Of Set 536| neverkino.
# Processing Record 537 Of Set 537| irun.
# Processing Record 538 Of Set 538| anadyr.
# Processing Record 539 Of Set 539| koulamoutou.
# Processing Record 540 Of Set 540| amahai.
# Processing Record 541 Of Set 541| karamea.
# City Not Found. Skipping.
# Processing Record 542 Of Set 542| egvekinot.
# Processing Record 543 Of Set 543| morrinhos.
# Processing Record 544 Of Set 544| phalaborwa.
# Processing Record 545 Of Set 545| yanam.
# Processing Record 546 Of Set 546| kristiinankaupunki.
# City Not Found. Skipping.
# Processing Record 547 Of Set 547| buchanan.
# Processing Record 548 Of Set 548| dire dawa.
# Processing Record 549 Of Set 549| lazaro cardenas.
# Processing Record 550 Of Set 550| gemena.
# Processing Record 551 Of Set 551| saint-louis.
# Processing Record 552 Of Set 552| shangrao.
# Processing Record 553 Of Set 553| juneau.
# Processing Record 554 Of Set 554| paamiut.
# Processing Record 555 Of Set 555| nishiwaki.
# Processing Record 556 Of Set 556| richards bay.
# Processing Record 557 Of Set 557| businga.
# Processing Record 558 Of Set 558| araouane.
# Processing Record 559 Of Set 559| sambava.
# Processing Record 560 Of Set 560| petrozavodsk.
# Processing Record 561 Of Set 561| malpe.
# Processing Record 562 Of Set 562| tarko-sale.
# Processing Record 563 Of Set 563| lakes entrance.
# Processing Record 564 Of Set 564| ishigaki.
# Processing Record 565 Of Set 565| thongwa.
# Processing Record 566 Of Set 566| crawfordsville.
# Processing Record 567 Of Set 567| duncan.
# Processing Record 568 Of Set 568| alice springs.
# Processing Record 569 Of Set 569| kununurra.
# Processing Record 570 Of Set 570| fatsa.
# Processing Record 571 Of Set 571| dudinka.
# Processing Record 572 Of Set 572| buta.
# Processing Record 573 Of Set 573| weyburn.
# Processing Record 574 Of Set 574| muroto.
# Processing Record 575 Of Set 575| shirokiy.
# Processing Record 576 Of Set 576| aberystwyth.
# Processing Record 577 Of Set 577| waddan.
# Processing Record 578 Of Set 578| luorong.
# Processing Record 579 Of Set 579| beloha.
# Processing Record 580 Of Set 580| nogliki.
# Processing Record 581 Of Set 581| illela.
# Processing Record 582 Of Set 582| vila.
# Processing Record 583 Of Set 583| bilibino.
# Processing Record 584 Of Set 584| gat.
# Processing Record 585 Of Set 585| boca do acre.
# Processing Record 586 Of Set 586| bukama.
# Processing Record 587 Of Set 587| mago.
# Processing Record 588 Of Set 588| samalaeulu.
# City Not Found. Skipping.
# Processing Record 589 Of Set 589| tiznit.
# Processing Record 590 Of Set 590| tabiauea.
# City Not Found. Skipping.
# Processing Record 591 Of Set 591| baykit.
# Processing Record 592 Of Set 592| mehriz.
# Processing Record 593 Of Set 593| auki.
# Processing Record 594 Of Set 594| warri.
# Processing Record 595 Of Set 595| malacacheta.
# Processing Record 596 Of Set 596| turukhansk.
# Processing Record 597 Of Set 597| sovetskiy.
# Processing Record 598 Of Set 598| danshui.
# Processing Record 599 Of Set 599| trairi.
# Processing Record 600 Of Set 600| elliot lake.
# Processing Record 601 Of Set 601| bairiki.
# City Not Found. Skipping.
# Processing Record 602 Of Set 602| sao gabriel da cachoeira.
# Processing Record 603 Of Set 603| natal.
# Processing Record 604 Of Set 604| chagda.
# City Not Found. Skipping.
# Processing Record 605 Of Set 605| hongjiang.
# Processing Record 606 Of Set 606| ust-kamchatsk.
# City Not Found. Skipping.
# Processing Record 607 Of Set 607| shingu.
# Processing Record 608 Of Set 608| ahuatempan.
# City Not Found. Skipping.
# Processing Record 609 Of Set 609| lyudinovo.
# Processing Record 610 Of Set 610| honghu.
# Processing Record 611 Of Set 611| ola.
# Processing Record 612 Of Set 612| aykino.
# Processing Record 613 Of Set 613| kampot.
# Processing Record 614 Of Set 614| aswan.
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_data.dropna(inplace = True) 
print(cities_data)
# Out:
#                     City name Cloudiness Country    Lat     Lng        Date  \
# 0                       Gamba         33      CN  28.28   88.52  1569879007
# 1                    tumannyy
# 2                     Kolyvan          0      RU  55.31   82.74  1569879007
# 3                      Hasaki         75      JP  35.73  140.83  1569878722
# 4                       Airai          0      TL  -8.93  125.41  1569879008
# 5                    Nichinan         75      JP  31.65  131.31  1569879009
# 6                        Nome         40      US  30.04  -94.42  1569879009
# 7                   Dalhousie         90      CA  48.06  -66.37  1569879009
# 8                      Broome        100      GB  52.47    1.45  1569878788
# 9                  Samagaltay         24      RU   50.6      95  1569879009
# 10                  Cape Town         20      ZA -33.93   18.42  1569878908
# 11                      Sitka         99      US  37.17  -99.65  1569879010
# 12                New Norfolk          0      AU -42.78  147.06  1569879010
# 13                    Gliwice          0      PL  50.29   18.67  1569879010
# 14                     Vostok         78      RU  46.45  135.83  1569879010
# 15               Saint George          0      GR  39.45   22.34  1569879011
# 16                 Filadelfia          0      PY -22.35  -60.04  1569879011
# 17                  Mount Isa          0      AU -20.73  139.49  1569879011
# 18                Yellowknife         75      CA  62.45 -114.38  1569879011
# 19                      Alofi         75      NU -19.06 -169.92  1569879012
# 20     grand river south east
# 21               Constitucion         75      MX  23.99 -104.67  1569879012
# 22                        Hue         40      VN  16.47  107.58  1569879012
# 23                   Tasiilaq         75      GL  65.61  -37.64  1569879012
# 24                     Lompoc          1      US  34.64 -120.46  1569878931
# 25                     Avarua        100      CK -21.21 -159.78  1569878820
# 26                  Thinadhoo        100      MV   0.53   72.93  1569878924
# 27                 Chokurdakh         72      RU  70.62   147.9  1569879013
# 28                      Bluff          0      AU -23.58  149.07  1569879013
# 29                   Hermanus          0      ZA -34.42   19.24  1569879013
# ..                        ...        ...     ...    ...     ...         ...
# 585              Boca do Acre        100      BR  -8.76  -67.39  1569879124
# 586                    Bukama        100      CD   -9.2   25.85  1569879125
# 587                      Mago         92      RU  53.27  140.15  1569879125
# 588                samalaeulu
# 589                    Tiznit        100      MA   29.7   -9.73  1569879125
# 590                  tabiauea
# 591                    Baykit         91      RU  61.68   96.39  1569879126
# 592                    Mehriz         20      IR  31.58   54.44  1569879126
# 593                      Auki         26      NG  12.18    6.51  1569879126
# 594                     Warri         98      NG   5.52    5.75  1569879126
# 595               Malacacheta          5      BR -17.84  -42.08  1569879127
# 596                Turukhansk         80      RU   65.8   87.96  1569878910
# 597                 Sovetskiy        100      RU  56.76   48.47  1569879127
# 598                   Danshui          0      CN  22.81  114.46  1569879127
# 599                    Trairi         53      BR  -3.28  -39.27  1569879127
# 600               Elliot Lake         90      CA  46.37  -82.65  1569879127
# 601                   bairiki
# 602  Sao Gabriel da Cachoeira         68      BR  -0.13  -67.09  1569879128
# 603                     Natal         20      BR  -5.81  -35.21  1569879128
# 604                    chagda
# 605                 Hongjiang          0      CN  27.21  109.83  1569879128
# 606             ust-kamchatsk
# 607                    Shingu         95      JP  33.72  135.99  1569879129
# 608                ahuatempan
# 609                 Lyudinovo         92      RU  53.86   34.45  1569879129
# 610                    Honghu         36      CN  29.82  113.46  1569879129
# 611                       Ola        100      RU  59.58   151.3  1569879130
# 612                    Aykino        100      RU  62.22   49.99  1569879130
# 613                    Kampot         75      KH  10.62  104.18  1569879130
# 614                     Aswan          0      EG  24.09    32.9  1569879130
#
#     Humidity Max temp Wind speed
# 0         76    34.25        3.4
# 1
# 2         80     35.6       6.71
# 3         94       68        4.7
# 4         79    68.63       2.86
# 5        100     69.8       3.36
# 6         55    91.99      11.41
# 7         53       50       3.36
# 8         93    57.99       9.17
# 9         49    23.99      10.11
# 10        82       61       6.93
# 11        61       82      21.99
# 12        70    46.99       6.93
# 13        66       57      16.11
# 14        93    48.29       2.62
# 15        82       68       3.18
# 16        18   105.53      21.12
# 17        22     78.8       5.82
# 18        56     44.6      19.46
# 19        74     80.6      12.75
# 20
# 21        43       75      12.75
# 22        88       77       3.36
# 23        52     42.8      17.22
# 24        40     78.8      19.46
# 25        64     73.4      12.75
# 26        81    81.05      14.43
# 27        94    22.73      10.49
# 28        29    69.35        9.4
# 29        95       57       4.21
# ..       ...      ...        ...
# 585       51    89.33       4.79
# 586       79    69.35       3.06
# 587       89    43.07        3.6
# 588
# 589       66    72.41       9.31
# 590
# 591       89    25.07       2.33
# 592       16     73.4       2.24
# 593       81    75.65       0.45
# 594       82    78.53       9.17
# 595       76    71.33        5.1
# 596       82    29.39       4.18
# 597       96    50.09      12.15
# 598       62       86       6.71
# 599       70    75.83       6.42
# 600      100     55.4      13.87
# 601
# 602       68    86.45       3.13
# 603       78     80.6      12.75
# 604
# 605       55    64.49        0.6
# 606
# 607       92    64.31       3.02
# 608
# 609       95    54.41      11.77
# 610       57    69.71        3.6
# 611       57    32.45       6.26
# 612       97    43.25       6.67
# 613       88     78.8       1.12
# 614       15       86      10.29
#
# [615 rows x 9 columns]

# %%
cities_data.count()
# Out:
# City name     615
# Cloudiness    615
# Country       615
# Lat           615
# Lng           615
# Date          615
# Humidity      615
# Max temp      615
# Wind speed    615
# dtype: int64

# %%
cities_data.head()
# Out:
#   City name Cloudiness Country    Lat     Lng        Date Humidity Max temp  \
# 0     Gamba         33      CN  28.28   88.52  1569879007       76    34.25
# 1  tumannyy
# 2   Kolyvan          0      RU  55.31   82.74  1569879007       80     35.6
# 3    Hasaki         75      JP  35.73  140.83  1569878722       94       68
# 4     Airai          0      TL  -8.93  125.41  1569879008       79    68.63
#
#   Wind speed
# 0        3.4
# 1
# 2       6.71
# 3        4.7
# 4       2.86

# %%
cities_data = cities_data.convert_objects(convert_numeric=True)
cities_data.dtypes
# Out:
# /Users/adeliamanuel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# City name      object
# Cloudiness    float64
# Country        object
# Lat           float64
# Lng           float64
# Date          float64
# Humidity      float64
# Max temp      float64
# Wind speed    float64
# dtype: object

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Max temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Max Temperature Plot(09/30/19)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatitudeVSTemperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Humidity"], marker="o",s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity Plot(09/30/19)")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatitudevsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Cloudiness"], marker="o",s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness(09/30/19)")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatitudevsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Wind speed"], marker="o",s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed(09/30/19)")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatitudevsWindSpeed.png")

# Show plot
plt.show()

# %%
#-----------Analysis----------------------
#Figure 1 for latitude vs temperature
# It looks like Latitude and temperature increases at the same time. 
#Or one depends on the other to either increase or decreased.

# Figure 2 latitude vs humidity
# For this figure, looks like the humidity and latitude is pretty high. 
#The regions are more diversified than the first figure.

# Figure 4 latitude vs wind speed
# In this figure, the wind speed is low. Most of the datas are down 20mph.
